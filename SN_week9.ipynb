# %% [markdown]
# ## Normal Distribution

# %% [markdown]
# Normal distribution, also known as the Gaussian distribution, is a probability distribution that is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data far from the mean.

# %% [markdown]
# ![Screenshot 2023-04-26 191518.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Power Law Distribution

# %% [markdown]
# The power law (also called the scaling law) states that a relative change in one quantity results in a proportional relative change in another.

# %% [markdown]
# ![power-law-basic.webp](data:image/webp;base64,...)

# %% [markdown]
# ![random-vs-power-law-distribution-2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Power Law in Web Graph

# %% [markdown]
# ![Screenshot 2023-04-26 192733.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Power law in real-life situations :
# * Distribution of telephone conversation duration (no of phone calls vs duration)
# * Distribution of song downloads
# * Distribution of the average wealth of a country’s citizens

# %% [markdown]
# ## Detecting the Presence of Power Law

# %% [markdown]
# ![Screenshot 2023-04-26 194502.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2023-04-26 194551.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# * Equation of the distribution that follows Power Law : f(k) = 1 / k^(alpha)
# * If one plots log f(k) vs log k and detects a straight line => f(k) follows power law distribution. And the slope of the straight line is alpha.

# %% [markdown]
# # Rich Gets Richer Phenomenon / Preferential Attachment

# %% [markdown]
# A person who is already rich gets more and more and a person who is having less gets less.

# %% [markdown]
# ## Barabasi-Albert Model

# %% [markdown]
# 1. Take a random graph with n0 nodes and connect them randomly with a condition that each has at least 1 link.
# 2. **Growth** : At each time we add a new node n which is less or equal to n0 links that will connect the new node to n nodes already in the network.
# 3. **Preferential Attachment** : Now the probability that a node connects to a particular node will depend on its degree.

# %% [markdown]
# ![Screenshot 2023-04-26 202439.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2023-04-26 202404.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Erdos-Renyi Model - Implementing Random Graph

# %% [markdown]
# A graph is constructed by connecting nodes randomly. Each edge is included in the graph with probability p independent from every other edge.

# %% [markdown]
# ![Screenshot 2023-04-26 203920.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2023-04-26 203938.jpg](data:image/jpeg;base64,...)
