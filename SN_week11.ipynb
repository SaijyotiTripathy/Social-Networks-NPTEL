# %% [markdown]
# ## The World is Connected

# %% [markdown]
# ### Small World Phenomenon - 6 degrees of separation

# %% [markdown]
# #### **Milgram's Experiment**
# #### The goal of the experiment was to find short chains of acquaintances linking pairs of people in the United States who did not know one another. In a typical instance of the experiment, a source person in Nebraska would be given a letter to deliver to a target person in Massachusetts. The source would initially be told basic information about the target, including his address and occupation; the source would then be instructed to send the letter to someone she knew on a first-name basis in an effort to transmit the letter to the target as efficaciously as possible. Anyone subsequently receiving the letter would be given the same instructions, and the chain of communication would continue until the target was reached. Roughly a third of the letters eventually arrived at the target, in a median of six steps, and this has since served as basic experimental evidence for the existence of short paths in the global friendship network, linking all (or almost all) of us together in society.
#
# #### **Conclusion**
# * #### Any two individuals in the network are likely to be connected through a short sequence of intermediate acquaintances.
# * #### 2 people are separated by 6 people on an average. (6 setps)

# %% [markdown]
# ![Screenshot 2023-04-05 182641.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# * #### Small world networks have small average shortest path (global) and high clustering coefficient (local)

# %% [markdown]
# #### **Watts-Strogatz Generative Model 1998**
# #### The authors start with a ring of n nodes, each connected to its k nearest neighbors by undirected edges. (For clarity, n = 20 and k = 4 in the schematic examples shown here.) They choose a node and the edge that connects it to its nearest neighbors in a clockwise sense. With a reconnection probability of p , they moved the edge to a node chosen uniformly at random over the entire ring, with a restriction on the duplicate edges; otherwise, they leave the edge in place. They repeat this process by moving clockwise around the ring, considering each node in turn until one lap is completed. Next, they consider the edges that connect nodes to their second nearest neighbors clockwise. As in the previous step, they randomly rewire each of these edges with a probability of p , repeating this process while circulating around the ring and proceeding outward to more distant neighbors after each lap, until each edge in the original lattice has been considered once. (As there are nk /2 edges in the entire graph, the rewiring process stops after k /2 laps.) Three realizations of this process are shown for different values of p .
#
# #### **Conclusion**
# * #### For p = 0, the original ring is unchanged
# * #### As p increases, the graph becomes increasingly disordered
# * #### For p = 1, all edges are rewired randomly.
#
# * #### One of their main results is that for intermediate values of p , the graph is a small-world network: highly clustered like a regular graph, yet with small characteristic path lengths similar to a random graph.

# %% [markdown]
# ![Small-world-network-Watts-and-Strogatz-1998-The-authors-start-with-a-ring-of-n-nodes.png](data:image/png;base64,...)

# %% [markdown]
# ### The Reason
#
# * #### Homophily
# * #### Weak Ties

# %% [markdown]
# ![Screenshot 2023-04-05 184120.jpg](data:image/jpeg;base64,...)
#
# #### In a grid like this, you tend to make more friends who are your neighbors/similar to you (homophily) and less friends who are not your neighbors(weak ties).

# %% [markdown]
# ![Screenshot 2023-04-05 183302.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### When P1 is trying to send a letter to P2, the letter may stay in the same city as P1 for some time since P1 knows more people in its city(homophily). But someone from that city may know someone from other city(weak ties) and it will pass on the letter. The process will repeat till the letter reaches P2.

# %% [markdown]
# * #### Milgram's experiment is a collaborative experiment. It uses local method.
# * #### Local Method - The person P1 only knows about his friends. He has no clue who the friends of P2 are. The person P1 sends the letter to one of his friends hoping that the letter will reach P2 and the same goes on with every single person.
# * #### Nobody knows the entire graph.

# %% [markdown]
# * #### Random rewiring in a generative model - Remove edges in a network and randomly add edges with a probability ‘p’
#
# * #### Probability that there's an edge between points P1 and P2 (given distance between them is d) = 1 / (d^k)
#
# * #### k can be any positive integer. But k=2 is the best possible value.
